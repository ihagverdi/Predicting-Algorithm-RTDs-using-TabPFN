# %% [markdown]
# # Load Data

# %%
from tabpfn_project.paths import RESULTS_DIR
from tabpfn_project.helper.utils import load_pickle

tabpfn_results_dir = RESULTS_DIR / "tabpfn"

tabpfn_scalerLOG = load_pickle(tabpfn_results_dir / "tabpfn_heatmap.pkl")

# %% [markdown]
# # Import Plotting Functions

# %%
from tabpfn_project.helper.utils import plot_ml_heatmap
from tabpfn_project.helper.utils import plot_heatmap_scatter

# %% [markdown]
# # Main Plot - All Heatmaps

# %%
results_dict = {"TabPFN": tabpfn_scalerLOG}

v_cfg = {"cmap": "rocket_r", "annot": True, "fmt": ".3f"}

fig = plot_ml_heatmap(
    results_data=results_dict,
    visual_config=v_cfg,
    plot_scenario=None,
    plot_metric=None,
)
# fig.savefig("heatmap_all.pdf", format="pdf", bbox_inches="tight")
